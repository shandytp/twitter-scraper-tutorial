# %% [markdown]
# # Notebook for Scraping

# %%
from main import scrape_tweets

# %%
query = "yoasobi since:2022-11-15 until:2022-12-06"

# %%
df = scrape_tweets(query=query, num_of_tweet=500)
df
# Out:
# 501it [00:22, 22.17it/s]
#                      Datetime             Tweet Id  \
# 0   2022-12-05 23:59:53+00:00  1599916500072402944
# 1   2022-12-05 23:59:20+00:00  1599916363598147586
# 2   2022-12-05 23:58:38+00:00  1599916186829213697
# 3   2022-12-05 23:57:32+00:00  1599915910101598208
# 4   2022-12-05 23:57:26+00:00  1599915884675756038
# ..                        ...                  ...
# 496 2022-12-05 18:42:43+00:00  1599836684300189696
# 497 2022-12-05 18:42:19+00:00  1599836581573316608
# 498 2022-12-05 18:41:42+00:00  1599836426534719491
# 499 2022-12-05 18:41:10+00:00  1599836291482673152
# 500 2022-12-05 18:41:06+00:00  1599836274860650496
#
#                                                   Text       Username
# 0    “lagu yoru ni kakeru itu sedih tau, cuma beat ...     noturbey__
# 1                             apkh w kudu stan yoasobi   swerbyonline
# 2              @04prn 夜に負ける/YOASOBI\n\nイク田りらの夜に負ける聴きたい  vufferin_p_dx
# ...

# %%
df.tail()
# Out:
#                      Datetime             Tweet Id  \
# 496 2022-12-05 18:42:43+00:00  1599836684300189696
# 497 2022-12-05 18:42:19+00:00  1599836581573316608
# 498 2022-12-05 18:41:42+00:00  1599836426534719491
# 499 2022-12-05 18:41:10+00:00  1599836291482673152
# 500 2022-12-05 18:41:06+00:00  1599836274860650496
#
#                                                   Text      Username
# 496                @convomf Yoasobi tracing that dream  kopi_dalgona
# 497  FYP GUA FULL YOASOBI SAMPE DETIK INI ASUUUUU W...      Ahabil21
# 498                               @drizinhuu yoasobi🤠🍷   gabrieorkjk
# 499  Screaming n crying from Jakarta getting YOASOB...    mang0m0chi
# 500  Ketika lu pertama kali melompat tangga\n\nModr...      raddixzz
